# %%
import pandas as pd
import numpy as np

# %%
from pyecharts import Line

attr =['2017', '2018', '2019', '2020']
v1 = [13.7-13.7,13.8-13.7,14-13.7,14.1-13.7]
v2 = [63.7-63.7,64.3-63.7,64.7-63.7,64.9-63.7]

v3 = [21.2-21.2,20.2-21.2,19.9-21.2,19.7-21.2]

v4 = [1.31-1.31,1.3-1.31,1.3-1.31,1.29-1.31]

line = Line("Variation of Proportion of each class")
line.add("Good", attr, v1)
line.add("Normal", attr, v2)
line.add("Critical", attr, v3)
line.add("Severe", attr, v4)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e0d5d5731f814aacb5658575c40411b7" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e0d5d5731f814aacb5658575c40411b7 = echarts.init(document.getElementById('e0d5d5731f814aacb5658575c40411b7'), 'light', {renderer: 'canvas'});
#
# var option_e0d5d5731f814aacb5658575c40411b7 = {
#     "title": [
#         {
#             "text": "Variation of Proportion of each class",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...
